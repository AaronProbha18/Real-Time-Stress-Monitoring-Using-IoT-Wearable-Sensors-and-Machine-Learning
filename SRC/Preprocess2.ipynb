# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
from statsmodels.multivariate.manova import MANOVA
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df = pd.read_csv("A:\InC4\SaafData.csv")

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# Timestamp            object
# Device Type          object
# Pulse                 int64
# Temp                float64
# Proximity            object
# Ambient Noise         int64
# Movement Pattern     object
# Stress Indicator     object
# User Behavior        object
# ZPulse              float64
# ZTemp               float64
# ZAmbNoise           float64
# dtype: object

# %%
plt.hist(df["ZTemp"])
# Out:
# (array([  4.,  17., 114., 160., 284., 196., 149.,  62.,  11.,   3.]),
#  array([-3.18300121, -2.52363339, -1.86426556, -1.20489774, -0.54552991,
#          0.11383792,  0.77320574,  1.43257357,  2.09194139,  2.75130922,
#          3.41067704]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df["ZPulse"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c177ba7910>,
#   <matplotlib.lines.Line2D at 0x2c177bbc610>],
#  'caps': [<matplotlib.lines.Line2D at 0x2c177bbd290>,
#   <matplotlib.lines.Line2D at 0x2c177bbde90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2c177b72f50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c177bbea10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c177bbf590>],
#  'means': []}

# %%
plt.boxplot(df["ZAmbNoise"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c179d5edd0>,
#   <matplotlib.lines.Line2D at 0x2c179d5f950>],
#  'caps': [<matplotlib.lines.Line2D at 0x2c179d685d0>,
#   <matplotlib.lines.Line2D at 0x2c179d69010>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2c179d5e190>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c179d69ad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c179d6a4d0>],
#  'means': []}

# %%
# find out covariance with respect  columns
cov_mat = np.stack((df["ZAmbNoise"], df["ZTemp"], df["ZPulse"]), axis = 0) 
print(np.cov(cov_mat))
# Out:
# [[ 1.          0.00360802 -0.04568749]
#  [ 0.00360802  1.          0.04851805]
#  [-0.04568749  0.04851805  1.        ]]
